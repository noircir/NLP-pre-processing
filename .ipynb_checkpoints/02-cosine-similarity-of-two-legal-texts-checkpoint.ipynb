# %%
# Description: create a program to see how similar are two texts.

# %%
# Install the docx2txt package
# !pip install docx2txt

# %%
import docx2txt

# %%
doc15 = docx2txt.process("/content/drive/My Drive/Colab Notebooks/Self-learning chatbot/document15.docx")

print(doc15)
# Out:
# APPEL D’OFFRES NO
#
#
#
# 	DOCUMENT D’APPEL D’OFFRES (Sans contrat intégré)	Page 2 de 3
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	Contrat	Travaux de construction & Services professionnels - 2 étapes
#
# 	Version détaillée	2019-12-20
#
#
#
#
#
# 	«Denom_Soc_D_O»	APPEL D’OFFRES NO «AO_No»
#
# 	«AO_Titre»
#
# 	Documentation d’appel d’offres
#
#
#
#
#
# APPEL D’OFFRES NO
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DOCUMENTATION D’APPELS D’OFFRES
#
#
#
# TRAVAUX DE CONSTRUCTION & SERVICES PROFESSIONNELS - 2 ÉTAPES
#
#
#
# CONTRAT
#
#
#
# Version détaillée
#
#
#
# (2019-12-20)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TABLE DES MATIÈRES
#
#
#
# PAGE
#
#
#
#
#
# 	PRÉAMBULE	6
#
# 		0.00	INTERPRÉTATION	6
#
# 		0.01	Terminologie	6
#
# 		0.01.01	Accord Intergouvernemental [Importante]	6
#
# 		0.01.02	Addenda [Essentielle]	6
#
# 		0.01.03	Avis d'Adjudication [Essentielle]	6
#
# ...

# %%
doc_master = docx2txt.process("/content/drive/My Drive/Colab Notebooks/Self-learning chatbot/document_master.docx")
#doc_master = docx2txt.process("/content/document15.docx")
print(doc_master)
# Out:
# MATRICE TRANSACTIONNELLE
#
# (Rédaction)
#
# MATRICE TRANSACTIONNELLE
#
# (Rédaction)
#
#
#
#
#
# CHAPITRE 0 – CONTRATS D’AFFAIRES
#
# CHAPITRE 0 – CONTRATS D’AFFAIRES
#
#
#
#
#
#
#
#
#
# 		DOCUMENT No. … 	MOIS 20…
#
#
#
#
#
#
#
#
#
#
#
# 		DOCUMENT No. Z03.200n 	AVRIL 2018 (01-19)
#
#
#
#
#
#
#
# 		DOCUMENT No 0003.200n	SEPTEMBRE 2017
#
#
#
#
#
#
#
#
#
#
#
# 	MATRICE TRANSACTIONNELLE (Version détaillée)	Page 115 de 130
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matrice transactionnelle
#
# (Version détaillée)
#
# matrice transactionnelle
#
# (Version détaillée)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AVIS ET LICENCE
#
#
#
# ...

# %%
# A list of text
text = [doc15, doc_master]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
count_matrix = cv.fit_transform(text)

# %%
from sklearn.metrics.pairwise import cosine_similarity

#Print the similarity scores
print("\nSimilarity Scores:")
print(cosine_similarity(count_matrix))
# Out:
# Similarity Scores:
# [[1.         0.90212703]
#  [0.90212703 1.        ]]

# %%
matchPercentage = cosine_similarity(count_matrix)[0][1] * 100
matchPercentage = round(matchPercentage, 2)
print("The two documents match about " + str(matchPercentage) + "%")
# Out:
# The two documents match about 90.21%

# %%
# From https://stackoverflow.com/questions/1746501/can-someone-give-an-example-of-cosine-similarity-in-a-very-simple-graphical-wa

import math
from collections import Counter

def build_vector(iterable1, iterable2):
    counter1 = Counter(iterable1)
    counter2 = Counter(iterable2)
    all_items = set(counter1.keys()).union(set(counter2.keys()))
    vector1 = [counter1[k] for k in all_items]
    vector2 = [counter2[k] for k in all_items]
    return vector1, vector2

def cosim(v1, v2):
    dot_product = sum(n1 * n2 for n1, n2 in zip(v1, v2) )
    magnitude1 = math.sqrt(sum(n ** 2 for n in v1))
    magnitude2 = math.sqrt(sum(n ** 2 for n in v2))
    return dot_product / (magnitude1 * magnitude2)

l1 = "Julie loves me more than Linda loves me".split()
l2 = "Jane likes me more than Julie loves me or".split()


v1, v2 = build_vector(l1, l2)
print(cosim(v1, v2))
# Out:
# 0.7833494518006403

# %%
print(v1)
# Out:
# [1, 1, 2, 0, 1, 0, 1, 0, 2]

# %%
print(v2)
# Out:
# [1, 0, 1, 1, 1, 1, 1, 1, 2]
