# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./resources/Liste-des-clauses-avec-toutes-les-taxonomies.csv', skipinitialspace=True, header=0, skiprows=2)
# Out:
# /Users/monty/anaconda3/envs/nlp/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (0,1,2,8,9,45,46,47,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(20)
# Out:
#            Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          RÉPERTOIRE         ID  VERSION ID    PUBLIÉE   DERNIÈRE        NaN
# 1   EDILEX INC. (224)        NaN         NaN        NaN        NaN        NaN
# 2                 NaN      76715      151535        Oui        Oui        NaN
# 3                 NaN        NaN         NaN        NaN        NaN        NaN
# 4                 NaN        NaN         NaN        NaN        NaN        NaN
# 5                 NaN     100619      124581        Oui        Oui        NaN
# 6                 NaN        NaN         NaN        NaN        NaN        NaN
# 7                 NaN        NaN         NaN        NaN        NaN        NaN
# 8                 NaN        NaN         NaN        NaN        NaN        NaN
# 9                 NaN        NaN         NaN        NaN        NaN        NaN
# 10                NaN        NaN         NaN        NaN        NaN        NaN
# 11                NaN        NaN         NaN        NaN        NaN        NaN
# 12                NaN        NaN         NaN        NaN        NaN        NaN
# 13                NaN        NaN         NaN        NaN        NaN        NaN
# 14                NaN        NaN         NaN        NaN        NaN     \n•\n
# 15                NaN        NaN         NaN        NaN        NaN        NaN
# 16                NaN        NaN         NaN        NaN        NaN     \n•\n
# 17                NaN        NaN         NaN        NaN        NaN        NaN
# 18                NaN        NaN         NaN        NaN        NaN     \n•\n
# 19                NaN        NaN         NaN        NaN        NaN        NaN
#
#                                            Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                              CLAUSE   DOCUMENT      POSTE
# 1                                                 NaN        NaN        NaN
# 2                          Contrat et accords verbaux          C         00
# 3    \nLe Contrat prime sur tout accord intervenu ...        NaN        NaN
# 4                                                 NaN        NaN        NaN
# 5                                        Renonciation          C         00
# 6    \nLa renonciation à l'exercice d'un droit con...        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                          De rigueur        NaN        NaN
# 9    \nToutes les échéances indiquées dans le Cont...        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                             Calcul        NaN        NaN
# 12   \nLors du calcul d'un délai, les règles suiva...        NaN        NaN
# 13                                                NaN        NaN        NaN
# 14   \nle jour qui marque le point de départ n'est...        NaN        NaN
# 15                                                NaN        NaN        NaN
# 16   \nles jours non ouvrables sont comptés; cepen...        NaN        NaN
# 17                                                NaN        NaN        NaN
# 18   \nle terme «mois», lorsqu'il est utilisé dans...        NaN        NaN
# 19                                                NaN        NaN        NaN
#
#    Unnamed: 9  ... STATUT DONNEUR D'ORDRE Unnamed: 60 Unnamed: 61  \
# 0        RANG  ...                   TOUT  INDIVIDUEL  MANDATAIRE
# 1         NaN  ...                    NaN         NaN         NaN
# 2           1  ...                      X         NaN         NaN
# 3         NaN  ...                    NaN         NaN         NaN
# 4         NaN  ...                    NaN         NaN         NaN
# 5           1  ...                      X         NaN         NaN
# 6         NaN  ...                    NaN         NaN         NaN
# 7         NaN  ...                    NaN         NaN         NaN
# 8         NaN  ...                    NaN         NaN         NaN
# 9         NaN  ...                    NaN         NaN         NaN
# 10        NaN  ...                    NaN         NaN         NaN
# 11        NaN  ...                    NaN         NaN         NaN
# 12        NaN  ...                    NaN         NaN         NaN
# 13        NaN  ...                    NaN         NaN         NaN
# 14        NaN  ...                    NaN         NaN         NaN
# 15        NaN  ...                    NaN         NaN         NaN
# 16        NaN  ...                    NaN         NaN         NaN
# 17        NaN  ...                    NaN         NaN         NaN
# 18        NaN  ...                    NaN         NaN         NaN
# 19        NaN  ...                    NaN         NaN         NaN
#
#                             Unnamed: 62 MODE D'ADJUDICATION       Unnamed: 64  \
# 0   MANDATAIRE GROUPE APPROVISIONNEMENT                TOUT  PRIX LE PLUS BAS
# 1                                   NaN                 NaN               NaN
# 2                                   NaN                   X               NaN
# 3                                   NaN                 NaN               NaN
# 4                                   NaN                 NaN               NaN
# 5                                   NaN                   X               NaN
# 6                                   NaN                 NaN               NaN
# 7                                   NaN                 NaN               NaN
# 8                                   NaN                 NaN               NaN
# 9                                   NaN                 NaN               NaN
# 10                                  NaN                 NaN               NaN
# 11                                  NaN                 NaN               NaN
# 12                                  NaN                 NaN               NaN
# 13                                  NaN                 NaN               NaN
# 14                                  NaN                 NaN               NaN
# 15                                  NaN                 NaN               NaN
# 16                                  NaN                 NaN               NaN
# 17                                  NaN                 NaN               NaN
# 18                                  NaN                 NaN               NaN
# 19                                  NaN                 NaN               NaN
#
#                                           Unnamed: 65  \
# 0   prix le plus bas groupes approvisionnement sou...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                          Unnamed: 66              Unnamed: 67  \
# 0   PRIX LE PLUS BAS QUALITÉ MINIMAL  PRIX AJUSTÉ LE PLUS BAS
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
# 5                                NaN                      NaN
# 6                                NaN                      NaN
# 7                                NaN                      NaN
# 8                                NaN                      NaN
# 9                                NaN                      NaN
# 10                               NaN                      NaN
# 11                               NaN                      NaN
# 12                               NaN                      NaN
# 13                               NaN                      NaN
# 14                               NaN                      NaN
# 15                               NaN                      NaN
# 16                               NaN                      NaN
# 17                               NaN                      NaN
# 18                               NaN                      NaN
# 19                               NaN                      NaN
#
#                    Unnamed: 68
# 0   NOTE FINALE LA PLUS ÉLEVÉE
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
#
# [20 rows x 69 columns]

# %%
df.columns = df.iloc[0]

# %%
df.drop(df.index[1])
# Out:
# 0                    RÉPERTOIRE      ID  VERSION ID  PUBLIÉE  DERNIÈRE  \
# 0                    RÉPERTOIRE      ID  VERSION ID  PUBLIÉE  DERNIÈRE
# 2                           NaN   76715      151535      Oui       Oui
# 3                           NaN     NaN         NaN      NaN       NaN
# 4                           NaN     NaN         NaN      NaN       NaN
# 5                           NaN  100619      124581      Oui       Oui
# ...                         ...     ...         ...      ...       ...
# 28866                       NaN     NaN         NaN      NaN       NaN
# 28867                       NaN     NaN         NaN      NaN       NaN
# 28868                       NaN     NaN         NaN      NaN       NaN
# 28869                       NaN     NaN         NaN      NaN       NaN
# 28870  Nombre total de clauses:     NaN        3881      NaN       NaN
#
# 0          NaN                                             CLAUSE  DOCUMENT  \
# 0          NaN                                             CLAUSE  DOCUMENT
# 2          NaN                         Contrat et accords verbaux         C
# 3          NaN   \nLe Contrat prime sur tout accord intervenu ...       NaN
# 4          NaN                                                NaN       NaN
# 5          NaN                                       Renonciation         C
# ...        ...                                                ...       ...
# 28866      NaN                                                NaN       NaN
# 28867   \n•\n    \nÀ compter de son adjudication, le Contrat à...       NaN
# 28868      NaN                                                NaN       NaN
# 28869      NaN                                                NaN       NaN
# 28870      NaN                                                NaN       NaN
#
# 0      POSTE  RANG  ...  TOUT  INDIVIDUEL  MANDATAIRE  \
# 0      POSTE  RANG  ...  TOUT  INDIVIDUEL  MANDATAIRE
# 2         00     1  ...     X         NaN         NaN
# 3        NaN   NaN  ...   NaN         NaN         NaN
# 4        NaN   NaN  ...   NaN         NaN         NaN
# 5         00     1  ...     X         NaN         NaN
# ...      ...   ...  ...   ...         ...         ...
# 28866    NaN   NaN  ...   NaN         NaN         NaN
# 28867    NaN   NaN  ...   NaN         NaN         NaN
# 28868    NaN   NaN  ...   NaN         NaN         NaN
# 28869    NaN   NaN  ...   NaN         NaN         NaN
# 28870    NaN   NaN  ...   NaN         NaN         NaN
#
# 0      MANDATAIRE GROUPE APPROVISIONNEMENT  TOUT  PRIX LE PLUS BAS  \
# 0      MANDATAIRE GROUPE APPROVISIONNEMENT  TOUT  PRIX LE PLUS BAS
# 2                                      NaN     X               NaN
# 3                                      NaN   NaN               NaN
# 4                                      NaN   NaN               NaN
# 5                                      NaN     X               NaN
# ...                                    ...   ...               ...
# 28866                                  NaN   NaN               NaN
# 28867                                  NaN   NaN               NaN
# 28868                                  NaN   NaN               NaN
# 28869                                  NaN   NaN               NaN
# 28870                                  NaN   NaN               NaN
#
# 0     prix le plus bas groupes approvisionnement soumissions électronique  \
# 0      prix le plus bas groupes approvisionnement sou...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# ...                                                  ...
# 28866                                                NaN
# 28867                                                NaN
# 28868                                                NaN
# 28869                                                NaN
# 28870                                                NaN
#
# 0      PRIX LE PLUS BAS QUALITÉ MINIMAL  PRIX AJUSTÉ LE PLUS BAS  \
# 0      PRIX LE PLUS BAS QUALITÉ MINIMAL  PRIX AJUSTÉ LE PLUS BAS
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
# 5                                   NaN                      NaN
# ...                                 ...                      ...
# 28866                               NaN                      NaN
# 28867                               NaN                      NaN
# 28868                               NaN                      NaN
# 28869                               NaN                      NaN
# 28870                               NaN                      NaN
#
# 0      NOTE FINALE LA PLUS ÉLEVÉE
# 0      NOTE FINALE LA PLUS ÉLEVÉE
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# ...                           ...
# 28866                         NaN
# 28867                         NaN
# 28868                         NaN
# 28869                         NaN
# 28870                         NaN
#
# [28870 rows x 69 columns]

# %%
plt.figure(figsize=(12,4))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %%
df['CLAUSE'].head(20)
# Out:
# 0                                                CLAUSE
# 1                                                   NaN
# 2                            Contrat et accords verbaux
# 3      \nLe Contrat prime sur tout accord intervenu ...
# 4                                                   NaN
# 5                                          Renonciation
# 6      \nLa renonciation à l'exercice d'un droit con...
# 7                                                   NaN
# 8                                            De rigueur
# 9      \nToutes les échéances indiquées dans le Cont...
# 10                                                  NaN
# 11                                               Calcul
# 12     \nLors du calcul d'un délai, les règles suiva...
# 13                                                  NaN
# 14     \nle jour qui marque le point de départ n'est...
# 15                                                  NaN
# 16     \nles jours non ouvrables sont comptés; cepen...
# 17                                                  NaN
# 18     \nle terme «mois», lorsqu'il est utilisé dans...
# 19                                                  NaN
# Name: CLAUSE, dtype: object

# %%
df['CLAUSE'][12]
# Out:
# " \nLors du calcul d'un délai, les règles suivantes s'appliquent\xa0:\n "

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28871 entries, 0 to 28870
# Data columns (total 69 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   RÉPERTOIRE                                                           3 non-null      object
#  1   ID                                                                   3882 non-null   object
#  2   VERSION ID                                                           3883 non-null   object
#  3   PUBLIÉE                                                              3882 non-null   object
#  4   DERNIÈRE                                                             3882 non-null   object
#  5   nan                                                                  4340 non-null   object
#  6   CLAUSE                                                               17664 non-null  object
#  7   DOCUMENT                                                             3882 non-null   object
#  8   POSTE                                                                3882 non-null   object
#  9   RANG                                                                 3882 non-null   object
#  10  PERTINENCE                                                           3882 non-null   object
#  11  PORTÉ                                                                3882 non-null   object
#  12  DISPONIBILITÉ                                                        3882 non-null   object
#  13  LCOP                                                                 3882 non-null   object
#  14  TOUT                                                                 2484 non-null   object
#  15  SANTÉ                                                                721 non-null    object
#  16  COMMISSION-SCOLAIRE                                                  419 non-null    object
#  17  CÉGEP
#                                                                417 non-null    object
#  18  UNIVERSITÉ                                                           283 non-null    object
#  19  SANTÉ-REGOUPEMENT                                                    952 non-null    object
#  20  GÉNÉRAL                                                              306 non-null    object
#  21  TOUT                                                                 2246 non-null   object
#  22  DÉTAILLÉE                                                            1526 non-null   object
#  23  SIMPLIFIÉE                                                           124 non-null    object
#  24  TOUT                                                                 134 non-null    object
#  25  BIENS                                                                589 non-null    object
#  26  BIENS TECHNIQUES                                                     585 non-null    object
#  27  BIENS ET SERVICES                                                    217 non-null    object
#  28  HAUTE TECHNOLOGIE                                                    469 non-null    object
#  29  HAUTE TECHNOLOGIE MSSS                                               470 non-null    object
#  30  SERVICES TECHNQUE                                                    496 non-null    object
#  31  SERVICES PROFESSIONNELS                                              488 non-null    object
#  32  SERVICES PROFESSIONNELS CONSTRUCITON                                 702 non-null    object
#  33  CONSTRUCTION                                                         563 non-null    object
#  34  CONSTRUCTION 2 ÉTAPRES                                               478 non-null    object
#  35  BIENS LOGICIEL                                                       490 non-null    object
#  36  BIEN ÉQUIPEMENT TI                                                   583 non-null    object
#  37  SERVICES INFORMATIQUES                                               576 non-null    object
#  38  BIENS LOGICIEL 2 ÉTAPES                                              476 non-null    object
#  39  BIEN ÉQUIPEMENT TI 2 ÉTAPES                                          570 non-null    object
#  40  SERVICES INFORMATIQUES 2 ÉTAPES                                      568 non-null    object
#  41  BIENS LOGICIEL 2 ÉTAPES DIALOGUE COMPÉTITIF                          439 non-null    object
#  42  BIEN ÉQUIPEMENT TI DIALOGUE COMPÉTITIF                               533 non-null    object
#  43  SERVICES INFORMATIQUES DIALOGUE COMPÉTITIF                           530 non-null    object
#  44  TOUT                                                                 3740 non-null   object
#  45  ÉTAPE 1                                                              59 non-null     object
#  46  ÉTAPE 2                                                              68 non-null     object
#  47  SANS                                                                 17 non-null     object
#  48  TOUT                                                                 3510 non-null   object
#  49  CONTRAT FERME                                                        184 non-null    object
#  50  CONTRAT A COMMANDE 1 FOURNISSEUR                                     54 non-null     object
#  51  CONTRAT A COMMANDE 2 FOURNISSEURS +                                  72 non-null     object
#  52  CONTRAT EXÉCUTION SUR DEMANDE 1 PRESTATAIRE                          107 non-null    object
#  53  nan                                                                  0 non-null      float64
#  54  CONTRAT EXÉCUTION SUR DEMANDE 2 PRESTATAIRE +                        109 non-null    object
#  55  TOUT                                                                 3161 non-null   object
#  56  PUBLIC                                                               355 non-null    object
#  57  INVITATION                                                           330 non-null    object
#  58  PUBLIC ÉLECTRONIQUE                                                  353 non-null    object
#  59  TOUT                                                                 3159 non-null   object
#  60  INDIVIDUEL                                                           302 non-null    object
#  61  MANDATAIRE                                                           364 non-null    object
#  62  MANDATAIRE GROUPE APPROVISIONNEMENT                                  355 non-null    object
#  63  TOUT                                                                 3043 non-null   object
#  64  PRIX LE PLUS BAS                                                     409 non-null    object
#  65  prix le plus bas groupes approvisionnement soumissions électronique  48 non-null     object
#  66  PRIX LE PLUS BAS QUALITÉ MINIMAL                                     304 non-null    object
#  67  PRIX AJUSTÉ LE PLUS BAS                                              370 non-null    object
#  68  NOTE FINALE LA PLUS ÉLEVÉE                                           206 non-null    object
# dtypes: float64(1), object(68)
# memory usage: 15.2+ MB
